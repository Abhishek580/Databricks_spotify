# %%
parameters = [
    {
        "table":"spotify_catalog.silver.factstream",
        "alias":"factstream",
        "cals":"factstream.stream_id,factstream.listen_duration"
    },
    {
        "table":"spotify_catalog.silver.dimuser",
        "alias":"dimuser",
        "cals":"dimuser.user_id,dimuser.user_name",
        "condition": "factstream.user_id = dimuser.user_id"
    },
    {
        "table":"spotify_catalog.silver.dimtrack",
        "alias":"dimtrack",
        "cals":"dimtrack.track_id,dimtrack.track_name",
        "condition":"factstream.track_id = dimtrack.track_id"
    }
]

# %%
pip install jinja2

# %%
from jinja2 import Template
template = """
SELECT 
    {% for param in parameters %}
        {{ param.cals }}
            {%if not loop.last %},{% endif %}
    {% endfor %} 
FROM
    {% for param in parameters %}
        {%if loop.first %}
            {{ param.table }} as {{ param.alias }}
        {% endif %}
    {% endfor %}
    {% for param in parameters %}
        {%if not loop.first %}
            LEFT JOIN
                {{ param.table }} AS {{ param.alias }}
            ON 
                {{ param.condition }}
        {% endif %}
           
    {% endfor %}
"""

# %%
jinja_sql_str = Template(template)
query = jinja_sql_str.render(parameters=parameters)
print(query)

# %%
data = spark.sql(query)
display(data)
